# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Oct 23 23:49:59 2021

@author: MV
"""

from random import randint
jogo=0
while jogo!=5:  
    
    def sort_Aleatório():
        L=[]
        N=int(input("Quantos números quer na lista? "))
        for i in range(N):
            elem=randint(0,100)
            L.append(elem)
        for i in range(N-1):
            for i in range(1,N):
                if L[i-1]>L[i]:
                    L[i],L[i-1]=L[i-1],L[i]
        return L
    
    def sort_Manual():
        L=[]
        N=int(input("Quantos números quer na lista? "))
        for i in range(N):
            I=int(input("Adicione um valor: "))
            L.append(I)
        for i in range(N-1):
            for i in range(1,N):
                if L[i-1]>L[i]:
                    L[i],L[i-1]=L[i-1],L[i]
        return L
    
    def máximo_Manual():
        M=0
        L=[]
        N=int(input("Quantos números quer na lista? "))
        for i in range(N):
            I=int(input("Adicione um valor: "))
            L.append(I)  
        for i in range(N):
            if L[i]>M:
                M=L[i]
        return M
    
    def máximo_Aleatório():
        M=0
        L=[]
        N=int(input("Quantos números quer na lista? "))
        for i in range(N):
            elem=randint(0,100)
            L.append(elem) 
        print (L)
        for i in range(N):
            if L[i]>M:
                M=L[i]
        return M        
        
    print("""Guião de listas de inteiros:
          (1)-Introduzir lista à mão
          (2)-Lista com valores aleatórios
          (3)-Maior elemento da lista
          (4)-Bubble Sort
          (5)-Sair""")
    jogo=input("Se quiser jogar, prima 0 senão prima 5.\n ")
    if jogo=="5":
        print("Até à próxima.")
        jogo=5
    elif jogo=="0":
        A=int(input("De que forma pretende construir a lista, (1) ou (2)? "))
        B=int(input("Que função pretende utilizar, (3) ou (4)? "))    
        if A==1 and B==3:
            M=máximo_Manual()
            print("O maior valor da lista é",str(M)+".\n")
        elif A==1 and B==4:
            L=sort_Manual()
            print(str(L)+"\n")
        elif A==2 and B==3:
            M=máximo_Aleatório()
            print("O maior valor da lista é",str(M)+".\n")
        elif A==2 and B==4:
            L=sort_Aleatório()
            print(str(L)+"\n")
    else:
        print("Escolha inválida!")
